# %%
# --- Para el proceso de datos y visualización ---
import numpy as np
import pandas as pd
import json 
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.mode.chained_assignment = None  # default='warn'
from google.cloud import storage



# --- Dependencias de Vertex AI ---
import vertexai                                              # Importa el módulo principal de Vertex AI.
from vertexai import init                                    # Inicializa Vertex AI con las credenciales y configuraciones necesarias.
from vertexai.vision_models import MultiModalEmbeddingModel  # Importa el modelo de embeddings multimodales de Vertex AI para procesar imágenes y videos.
from vertexai.vision_models import Video                     # Clase para manejar archivos de video en Vertex AI.
from vertexai.vision_models import VideoSegmentConfig        # Configuración para segmentar videos al gener
from google.cloud.aiplatform.matching_engine import MatchingEngineIndexEndpoint 
from vertexai.vision_models import Image

# --- Dependencias para poder visualizar ---
from IPython.display import Video as MVideo                  # Permite mostrar videos directamente en celdas de Jupyter Notebook.
from IPython.display import HTML                             # Permite mostrar contenido HTML en celdas de Jupyter Notebook.
from IPython.display import Image as ImageByte               # Permite mostrar imágenes en el notebook (renombrado como ImageByte para evitar conflictos de nombres).
from IPython.display import display                          # Función general para mostrar objetos en el notebook.
from sklearn.metrics.pairwise import cosine_similarity       # Función para calcular la similitud coseno entre vectores, útil para comparar embeddings.
from vertexai.vision_models import Video, VideoSegmentConfig

# %%
# --- Cargamos el modelo de embeddings multimodales ---
mm_embendding_model = MultiModalEmbeddingModel.from_pretrained("multimodalembedding@001")

# %%
# --- Cargamos las credewntiales de Vertex AI ---

PROJECT_ID = "dauntless-drive-462416-q3"
LOCATION = "us-central1"


# --- Inicializamos Vertex AI ---
init(project = PROJECT_ID, location = LOCATION)

# %%
import os
import subprocess
from google.cloud import storage

def fragmentar_video_local_ffmpeg(
    ruta_video_local: str,
    gcs_bucket_salida: str,
    duracion_segmento: int,
    carpeta_tmp: str = "/tmp"
):
    """
    Fragmenta un video local en segmentos de X segundos usando ffmpeg y sube SOLO los fragmentos a un bucket de GCS.
    """
    nombre_base = os.path.splitext(os.path.basename(ruta_video_local))[0]
    storage_client = storage.Client()
    bucket_out = storage_client.bucket(gcs_bucket_salida)

    # Fragmentar con ffmpeg
    output_pattern = os.path.join(carpeta_tmp, f"{nombre_base}_segment_%03d.mkv")
    cmd = [
        "ffmpeg",
        "-i", ruta_video_local,
        "-c", "copy",
        "-map", "0",
        "-f", "segment",
        "-segment_time", str(duracion_segmento),
        output_pattern
    ]
    print("Fragmentando video con ffmpeg...")
    subprocess.run(cmd, check=True)

    # Subir SOLO los fragmentos al bucket de salida
    fragmentos = sorted([
        f for f in os.listdir(carpeta_tmp)
        if f.startswith(f"{nombre_base}_segment_") and f.endswith(".mkv")
    ])
    print(f"Subiendo {len(fragmentos)} fragmentos a gs://{gcs_bucket_salida}/ ...")
    for frag in fragmentos:
        local_path = os.path.join(carpeta_tmp, frag)
        blob_dest = f"{nombre_base}/{frag}"
        bucket_out.blob(blob_dest).upload_from_filename(local_path)
        print(f"  ✅ Subido: gs://{gcs_bucket_salida}/{blob_dest}")

    # Limpiar archivos temporales
    for frag in fragmentos:
        os.remove(os.path.join(carpeta_tmp, frag))
    print("¡Listo!")

# Ejemplo de uso:
fragmentar_video_local_ffmpeg(
    ruta_video_local="/Users/wivboost/Downloads/azteca7_recording.mkv",
    gcs_bucket_salida="fragmentaciones",
    duracion_segmento=20  # segundos
)
# Out:
# Fragmentando video con ffmpeg...
# ffmpeg version 7.1.1 Copyright (c) 2000-2025 the FFmpeg developers
#   built with Apple clang version 17.0.0 (clang-1700.0.13.3)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/7.1.1_3 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      59. 39.100 / 59. 39.100
#   libavcodec     61. 19.101 / 61. 19.101
#   libavformat    61.  7.100 / 61.  7.100
#   libavdevice    61.  3.100 / 61.  3.100
#   libavfilter    10.  4.100 / 10.  4.100
#   libswscale      8.  3.100 /  8.  3.100
#   libswresample   5.  3.100 /  5.  3.100
#   libpostproc    58.  3.100 / 58.  3.100
# Input #0, matroska,webm, from '/Users/wivboost/Downloads/azteca7_recording.mkv':
#   Metadata:
#     ENCODER         : Lavf61.1.100
#   Duration: 02:14:26.07, start: 0.000000, bitrate: 3001 kb/s
#   Stream #0:0: Video: h264 (High), yuv420p(tv, bt709, progressive), 852x480 [SAR 1:1 DAR 71:40], 30 fps, 30 tbr, 1k tbn
#       Metadata:
#         DURATION        : 02:14:26.066000000
#   Stream #0:1: Audio: aac (LC), 48000 Hz, stereo, fltp
#       Metadata:
#         title           : simple_aac_recording0
#         DURATION        : 02:14:25.984000000
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_000.mkv' for writing
# Output #0, segment, to '/tmp/azteca7_recording_segment_%03d.mkv':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Stream #0:0: Video: h264 (High), yuv420p(tv, bt709, progressive), 852x480 [SAR 1:1 DAR 71:40], q=2-31, 30 fps, 30 tbr, 1k tbn
#       Metadata:
#         DURATION        : 02:14:26.066000000
#   Stream #0:1: Audio: aac (LC), 48000 Hz, stereo, fltp
#       Metadata:
#         title           : simple_aac_recording0
#         DURATION        : 02:14:25.984000000
# Press [q] to stop, [?] for help
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_001.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_002.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_003.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_004.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_005.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_006.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_007.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_008.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_009.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_010.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_011.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_012.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_013.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_014.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_015.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_016.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_017.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_018.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_019.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_020.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_021.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_022.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_023.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_024.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_025.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_026.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_027.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_028.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_029.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_030.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_031.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_032.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_033.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_034.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_035.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_036.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_037.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_038.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_039.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_040.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_041.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_042.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_043.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_044.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_045.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_046.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_047.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_048.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_049.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_050.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_051.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_052.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_053.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_054.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_055.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_056.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_057.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_058.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_059.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_060.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_061.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_062.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_063.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_064.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_065.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_066.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_067.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_068.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_069.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_070.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_071.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_072.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_073.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_074.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_075.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_076.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_077.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_078.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_079.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_080.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_081.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_082.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_083.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_084.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_085.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_086.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_087.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_088.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_089.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_090.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_091.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_092.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_093.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_094.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_095.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_096.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_097.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_098.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_099.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_100.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_101.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_102.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_103.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_104.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_105.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_106.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_107.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_108.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_109.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_110.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_111.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_112.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_113.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_114.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_115.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_116.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_117.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_118.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_119.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_120.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_121.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_122.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_123.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_124.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_125.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_126.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_127.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_128.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_129.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_130.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_131.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_132.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_133.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_134.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_135.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_136.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_137.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_138.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_139.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_140.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_141.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_142.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment_143.mkv' for writing
# [segment @ 0x138908040] Opening '/tmp/azteca7_recording_segment
mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_055.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_056.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_057.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_058.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_059.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_060.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_061.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_062.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_063.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_064.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_065.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_066.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_067.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_068.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_069.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_070.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_071.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_072.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_073.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_074.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_075.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_076.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_077.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_078.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_079.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_080.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_081.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_082.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_083.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_084.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_085.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_086.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_087.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_088.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_089.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_090.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_091.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_092.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_093.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_094.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_095.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_096.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_097.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_098.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_099.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_100.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_101.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_102.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_103.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_104.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_105.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_106.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_107.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_108.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_109.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_110.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_111.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_112.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_113.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_114.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_115.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_116.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_117.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_118.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_119.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_120.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_121.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_122.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_123.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_124.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_125.mkv
# ...
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_216.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_217.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_218.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_219.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_220.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_221.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_222.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_223.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_224.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_225.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_226.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_227.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_228.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_229.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_230.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_231.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_232.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_233.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_234.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_235.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_236.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_237.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_238.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_239.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_240.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_241.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_242.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_243.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_244.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_245.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_246.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_247.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_248.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_249.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_250.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_251.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_252.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_253.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_254.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_255.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_256.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_257.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_258.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_259.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_260.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_261.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_262.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_263.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_264.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_265.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_266.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_267.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_268.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_269.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_270.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_271.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_272.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_273.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_274.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_275.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_276.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_277.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_278.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_279.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_280.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_281.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_282.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_283.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_284.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_285.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_286.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_287.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_288.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_289.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_290.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_291.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_292.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_293.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_294.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_295.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_296.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_297.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_298.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_299.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_300.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_301.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_302.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_303.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_304.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_305.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_306.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_307.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_308.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_309.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_310.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_311.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_312.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_313.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_314.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_315.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_316.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_317.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_318.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_319.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_320.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_321.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_322.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_323.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_324.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_325.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_326.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_327.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_328.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_329.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_330.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_331.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_332.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_333.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_334.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_335.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_336.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_337.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_338.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_339.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_340.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_341.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_342.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_343.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_344.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_345.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_346.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_347.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_348.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_349.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_350.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_351.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_352.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_353.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_354.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_355.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_356.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_357.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_358.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_359.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_360.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_361.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_362.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_363.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_364.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_365.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_366.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_367.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_368.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_369.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_370.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_371.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_372.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_373.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_374.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_375.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_376.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_377.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_378.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_379.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_380.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_381.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_382.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_383.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_384.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_385.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_386.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_387.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_388.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_389.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_390.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_391.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_392.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_393.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_394.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_395.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_396.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_397.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_398.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_399.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_400.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_401.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_402.mkv
#   ✅ Subido: gs://fragmentaciones/azteca7_recording/azteca7_recording_segment_403.mkv
# ¡Listo!

# %%
def get_video_embedding(ruta_video: str) -> list: 
    
    """
    Genera un embedding para un video dado.

    Args:
        ruta_video (str): Ruta al archivo de video.

    Returns:
        list: Embedding del video.
    """
    # Cargamos el video desde la ruta proporcionada
    video = Video.load_from_file(ruta_video)
    
    # Genera el embedding del video utilizando el modelo de embeddings multimodales
    embedding = mm_embendding_model.get_embeddings(video = video, 
                                                   video_segment_config = VideoSegmentConfig(interval_sec=4) # Configura el segmento del video para generar embeddings cada 4 segundos.
                                                  )
    
    return [video_emb.embedding for video_emb in embedding.video_embeddings]  # Retorna una lista de embeddings para cada segmento del video.

# %%
def guardar_embeddings_en_gcs_json(
    project_id: str,
    bucket_name: str,
    blob_name: str,
    ids: list[str],
    embeddings: list[list[float]]
):
    """
    Guarda los embeddings en un solo archivo JSON en GCS.
    """
    import json
    print(f"Conectando al bucket '{bucket_name}'...")
    storage_client = storage.Client(project=project_id)
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(blob_name)

    # Prepara los datos como una lista de diccionarios
    data = [{"id": i, "embedding": emb} for i, emb in zip(ids, embeddings)]

    print(f"Escribiendo {len(ids)} embeddings en formato JSON...")
    # Escribe el archivo JSON en GCS
    blob.upload_from_string(
        data=json.dumps(data, ensure_ascii=False, indent=2),
        content_type="application/json"
    )
    print(f"¡Éxito! Archivo '{blob_name}' subido correctamente a 'gs://{bucket_name}/{blob_name}'.")

# %%
import os
from google.cloud import storage
import json

def procesar_fragmentos_y_guardar_embeddings(
    project_id: str,
    bucket_name: str,
    carpeta_fragmentos: str,
    carpeta_tmp: str = "/tmp"
):
    """
    Descarga cada fragmento de video de GCS, genera embeddings y los guarda en el mismo bucket
    en una carpeta con el sufijo '_embeddings'.
    """
    storage_client = storage.Client(project=project_id)
    bucket = storage_client.bucket(bucket_name)
    carpeta_embeddings = carpeta_fragmentos + "_embeddings"

    blobs = list(storage_client.list_blobs(bucket_name, prefix=carpeta_fragmentos + "/"))
    fragmentos = [blob.name for blob in blobs if blob.name.endswith(".mkv")]

    print(f"Procesando {len(fragmentos)} fragmentos...")

    for frag_blob_name in fragmentos:
        frag_local = os.path.join(carpeta_tmp, os.path.basename(frag_blob_name))
        bucket.blob(frag_blob_name).download_to_filename(frag_local)
        print(f"Descargado: {frag_blob_name}")

        embeddings = get_video_embedding(frag_local)
        ids = [f"{os.path.basename(frag_blob_name)}_seg{i}" for i in range(len(embeddings))]

        emb_blob_name = f"{carpeta_embeddings}/embeddings_{os.path.basename(frag_blob_name)}.jsonl"
        guardar_embeddings_en_gcs_json(
            project_id=project_id,
            bucket_name=bucket_name,
            blob_name=emb_blob_name,
            ids=ids,
            embeddings=embeddings
        )
        print(f"  ✅ Embeddings guardados: gs://{bucket_name}/{emb_blob_name}")

        os.remove(frag_local)
    print("¡Listo!")

# %%
def procesar_fragmentos_y_guardar_embeddings(
    project_id: str,
    bucket_name: str,
    carpeta_fragmentos: str,
    carpeta_tmp: str = "/tmp"
):
    """
    Descarga cada fragmento de video de GCS, genera embeddings y los guarda en el mismo bucket
    en una carpeta con el sufijo '_embeddings', en formato JSON.
    """
    storage_client = storage.Client(project=project_id)
    bucket = storage_client.bucket(bucket_name)
    carpeta_embeddings = carpeta_fragmentos + "_embeddings"

    blobs = list(storage_client.list_blobs(bucket_name, prefix=carpeta_fragmentos + "/"))
    fragmentos = [blob.name for blob in blobs if blob.name.endswith(".mkv")]

    print(f"Procesando {len(fragmentos)} fragmentos...")

    for frag_blob_name in fragmentos:
        frag_local = os.path.join(carpeta_tmp, os.path.basename(frag_blob_name))
        bucket.blob(frag_blob_name).download_to_filename(frag_local)
        print(f"Descargado: {frag_blob_name}")

        embeddings = get_video_embedding(frag_local)
        ids = [f"{os.path.basename(frag_blob_name)}_seg{i}" for i in range(len(embeddings))]

        emb_blob_name = f"{carpeta_embeddings}/embeddings_{os.path.basename(frag_blob_name)}.json"
        guardar_embeddings_en_gcs_json(
            project_id=project_id,
            bucket_name=bucket_name,
            blob_name=emb_blob_name,
            ids=ids,
            embeddings=embeddings
        )
        print(f"  ✅ Embeddings guardados: gs://{bucket_name}/{emb_blob_name}")

        os.remove(frag_local)
    print("¡Listo!")

# Ejemplo de uso:
procesar_fragmentos_y_guardar_embeddings(
    project_id="dauntless-drive-462416-q3",
    bucket_name="fragmentaciones",
    carpeta_fragmentos="azteca7_recording"
)
# Out:
# Procesando 404 fragmentos...
# Descargado: azteca7_recording/azteca7_recording_segment_000.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 6 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_000.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_000.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_000.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_001.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 5 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_001.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_001.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_001.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_002.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 6 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_002.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_002.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_002.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_003.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 5 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_003.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_003.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_003.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_004.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 6 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_004.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_004.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_004.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_005.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 7 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_005.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_005.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_005.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_006.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 5 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_006.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_006.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_006.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_007.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 5 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_007.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_007.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_007.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_008.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 7 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_008.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_008.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_008.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_009.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 5 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_009.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_009.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_009.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_010.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 7 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_010.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_010.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_010.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_011.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 5 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_011.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_011.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_011.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_012.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 5 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_012.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_012.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_012.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_013.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 7 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_013.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_013.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_013.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_014.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 4 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_014.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_014.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_014.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_015.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 6 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_015.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_015.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_015.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_016.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 7 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_016.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_016.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_016.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_017.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 4 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_017.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_017.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_017.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_018.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 6 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_018.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_018.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_018.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_019.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 5 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_019.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_019.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_019.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_020.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 6 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_020.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_020.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_020.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_021.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 5 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_021.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_021.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_021.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_022.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 6 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_022.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_022.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_022.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_023.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 6 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_023.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_023.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_023.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_024.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 5 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_024.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_024.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_024.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_025.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 6 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_025.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_025.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_025.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_026.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 5 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_026.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_026.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_026.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_027.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 7 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_027.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_027.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_027.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_028.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 5 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_028.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_028.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_028.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_029.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 5 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_029.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_029.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_029.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_030.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 6 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_030.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_030.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_030.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_031.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 6 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_031.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_031.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_031.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_032.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 6 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_032.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_032.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_032.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_033.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 5 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_033.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_033.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_033.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_034.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 6 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_034.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_034.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_034.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_035.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 5 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_035.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_035.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_035.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_036.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 7 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_036.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_036.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_036.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_037.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 5 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_037.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_037.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_037.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_038.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 5 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_038.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_038.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_038.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_039.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 7 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_039.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_039.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_039.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_040.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 5 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_040.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_040.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_040.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_041.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 6 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_041.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_041.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_041.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_042.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 5 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_042.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_042.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_042.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_043.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 7 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_043.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_043.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_043.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_044.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 5 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_044.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_044.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_044.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_045.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 5 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_045.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_045.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_045.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_046.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 6 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_046.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_046.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_046.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_047.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 5 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_047.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_047.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_047.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_048.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 7 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_048.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_048.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_048.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_049.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 4 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_049.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_049.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_049.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_050.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 6 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_050.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_050.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_050.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_051.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 6 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_051.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_051.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_051.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_052.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 5 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_052.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_052.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_052.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_053.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 6 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_053.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_053.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_053.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_054.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 6 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_054.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_054.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_054.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_055.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 5 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment_055.mkv.json' subido correctamente a 'gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_055.mkv.json'.
#   ✅ Embeddings guardados: gs://fragmentaciones/azteca7_recording_embeddings/embeddings_azteca7_recording_segment_055.mkv.json
# Descargado: azteca7_recording/azteca7_recording_segment_056.mkv
# Conectando al bucket 'fragmentaciones'...
# Escribiendo 7 embeddings en formato JSON...
# ¡Éxito! Archivo 'azteca7_recording_embeddings/embeddings_azteca7_recording_segment