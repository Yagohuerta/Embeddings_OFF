# %% [markdown]
# # **Importamos las dependencias**

# %%
# --- Importaciones para Manejo de Archivos y Directorios ---
import os
import sys
import subprocess
import re

from google.cloud import storage
from typing import List

import math

# --- Importamos Vertex AI ---
import vertexai


# --- Importaciones para Visualización y Formato de Texto ---

# Se utiliza para mostrar contenido enriquecido, como texto con formato Markdown,
# directamente en entornos como Jupyter Notebooks o IPython.
from IPython.display import Markdown, display

# Importa la clase `Markdown` de la biblioteca `rich`, que sirve para renderizar
# Markdown con formato avanzado en la terminal. Se le da un alias `RichMarkdown`
# para evitar conflictos de nombre con la importación anterior.
from rich.markdown import Markdown as RichMarkdown


# --- Importaciones para el Modelo Generativo de Vertex AI ---

# Importa las clases necesarias del SDK de Vertex AI para interactuar con los modelos generativos.
# - GenerationConfig: Para configurar los parámetros de la respuesta (ej. temperatura, top_p).
# - GenerativeModel: La clase principal para cargar y usar un modelo generativo como Gemini.
# - Image: Para manejar y enviar imágenes como parte de la entrada al modelo (enfoque multimodal).
from vertexai.generative_models import GenerationConfig, GenerativeModel, Image

# %%
# --- Para el proceso de datos y visualización ---
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import time


# --- Para manejar las variables de entorno ---
import os
from dotenv import load_dotenv


# --- Desactiva las advertencias de asignaciones encadenadas en pandas para evitar mensajes de warning al modificar DataFrames.
pd.options.mode.chained_assignment = None  # default='warn'


# --- Dependencias de Vertex AI ---
import vertexai                                              # Importa el módulo principal de Vertex AI.
from vertexai import init                                    # Inicializa Vertex AI con las credenciales y configuraciones necesarias.
from vertexai.vision_models import Image as VMImage          # Importa la clase Image de Vertex AI para manejar imágenes.
from vertexai.vision_models import MultiModalEmbeddingModel  # Importa el modelo de embeddings multimodales de Vertex AI para procesar imágenes y videos.
from vertexai.vision_models import Video                     # Clase para manejar archivos de video en Vertex AI.
from vertexai.vision_models import VideoSegmentConfig        # Configuración para segmentar videos
from vertexai.generative_models import GenerativeModel       # Importa la clase para modelos generativos, como Gemini.
from vertexai.generative_models import Part                  # Importa la clase Part para manejar partes de un mensaje, como texto o imágenes.


# --- Para conectarse y consultar un endpoint de búsqueda vectorial (Vector Search) en Vertex AI. 
from google.cloud.aiplatform.matching_engine import MatchingEngineIndexEndpoint 

# --- Para acceder a los buckets de Google Cloud Storage y manejar archivos.
from google.cloud import storage


# --- Dependencias para poder visualizar ---
from IPython.display import Video as MVideo                  # Permite mostrar videos directamente en celdas de Jupyter Notebook.
from IPython.display import HTML                             # Permite mostrar contenido HTML en celdas de Jupyter Notebook.
from IPython.display import Image as ImageByte               # Permite mostrar imágenes en el notebook (renombrado como ImageByte para evitar conflictos de nombres).
from IPython.display import display                          # Función general para mostrar objetos en el notebook.
from sklearn.metrics.pairwise import cosine_similarity       # Función para calcular la similitud coseno entre vectores, útil para comparar embeddings.

# %%
from vertexai.generative_models import GenerationConfig
from vertexai.generative_models import GenerationResponse

# %% [markdown]
# # **Configuración de las credenciales**

# %%
# --- Carga las Variables de Entorno ---
load_dotenv()

PROJECT_ID = os.getenv("PROJECT_ID")                        # ID del proyecto de Google Cloud
LOCATION = os.getenv("LOCATION")                            # Región donde se encuentran los recursos de Vertex AI
INDEX_ID = os.getenv("INDEX_ID")                            # ID del índice de búsqueda vectorial en Vertex AI
ENDPOINT_ID = os.getenv("ENDPOINT_ID")                      # ID del endpoint de búsqueda vectorial en Vertex AI
BUCKET_NAME = os.getenv("BUCKET_NAME")                      # Nombre del bucket de Google Cloud Storage donde se almacenan los videos
VIDEO_FOLDER_PATH = os.getenv("VIDEO_FOLDER_PATH")          # Ruta del folder dentro del bucket donde se encuentran los videos

# Verificamos que las variebles de entorno esten bien
# print(f"Proyecto: {PROJECT_ID}, Ubicación: {LOCATION}, Índice: {INDEX_ID}, Endpoint: {ENDPOINT_ID}, Bucket: {BUCKET_NAME}, Ruta de Videos: {VIDEO_FOLDER_PATH}")
# Out:
# python-dotenv could not parse statement starting at line 3
# python-dotenv could not parse statement starting at line 4
# python-dotenv could not parse statement starting at line 5
# python-dotenv could not parse statement starting at line 7
# python-dotenv could not parse statement starting at line 15
# python-dotenv could not parse statement starting at line 16
# python-dotenv could not parse statement starting at line 17
# python-dotenv could not parse statement starting at line 19
# python-dotenv could not parse statement starting at line 28
# python-dotenv could not parse statement starting at line 29
# python-dotenv could not parse statement starting at line 30
# python-dotenv could not parse statement starting at line 32
# python-dotenv could not parse statement starting at line 33

# %%
# Iniciamos Vertex AI con el proyecto y la ubicación especificados.
init(project = PROJECT_ID, location = LOCATION)

# %%
# --- Inicialización del LLM ---
# model = GenerativeModel('gemini-2.5-flash') # Debo probar con varios modelos, para ver cual tiene mejor rendimiento.

# %% [markdown]
# # **Funciones**

# %%
def obtener_nombres_de_archivos(nombre_bucket: str, nombre_carpeta: str) -> List[str]:
    """
    Obtiene una lista con los nombres de los archivos de una "carpeta" en un bucket.

    Args:
        nombre_bucket: El nombre del bucket de Cloud Storage.
        nombre_carpeta: La ruta de la carpeta (prefijo) dentro del bucket.

    Returns:
        Una lista de strings con los nombres de los archivos.
        Retorna una lista vacía si la carpeta no existe o hay un error.
    """
    try:
        cliente_storage = storage.Client()
        nombres_archivos = []

        # Aseguramos que el prefijo termine con '/' para que actúe como una carpeta
        if nombre_carpeta and not nombre_carpeta.endswith('/'):
            nombre_carpeta += '/'

        # Usamos el parámetro 'prefix' para filtrar por la carpeta
        blobs = cliente_storage.list_blobs(nombre_bucket, prefix=nombre_carpeta)

        for blob in blobs:
            # Obtiene el nombre del archivo relativo a la carpeta que estamos viendo
            nombre_relativo = blob.name.replace(nombre_carpeta, '', 1)
            if nombre_relativo: # Evita añadir una entrada vacía si la carpeta misma aparece
                nombres_archivos.append(nombre_relativo)
        
        return nombres_archivos

    except Exception as e:
        print(f"Ocurrió un error al acceder al bucket: {e}")
        return []

# %%
def reporteGemini(uri, marca_a_buscar, temperatura=0.0):

    """
    Analiza el video y te devuelve la data de las apariciones de la marca
    """

    # --- Configuración del modelo ---

    # Construimos la uri completa (solo tenemos el nombre del archivo)
    uri = 'gs://vboxiooof/Videos/Videos_Segmentados/'+uri


    # Preparamos al video en el formato que puede consumir Gemini
    video = Part.from_uri(uri=uri, mime_type='video/mkv')

    # Configuramos otros parámetros del modelo de Gemini
    generation_config = {'temperature': temperatura} 

    # Definimos el system prompt
    # Reemplaza tu system_instruction con esta nueva versión más precisa

    # Reemplaza tu system_instruction con esta versión HÍBRIDA

    system_instruction = """
Eres un analista de medios y publicidad de élite. Tu análisis debe ser contextual y preciso, siguiendo un proceso de decisión en dos etapas.

---
**ETAPA 1: ANÁLISIS DEL CONTEXTO GENERAL DEL CLIP**
---
Primero, evalúa la naturaleza general del video completo.
- ¿Es una **Transmisión en Vivo** del partido, mostrando el juego, a los jugadores en la cancha o a los fans en las gradas, sobre la cual se superponen gráficos?
- ¿O es un **Anuncio Producido**, que interrumpe el juego para contar una historia o mensaje publicitario con edición cinematográfica, música y actores, aunque muestre escenas de fútbol?

**Esta primera evaluación es la más importante.**

---
**ETAPA 2: CLASIFICACIÓN BASADA EN EL CONTEXTO**
---
Una vez determinado el contexto, aplica la siguiente regla:

1.  **Si el contexto es un 'Anuncio Producido':**
    La respuesta DEBE contener una única entrada para la marca. Usa la categoría **'Anuncio'** para la duración completa del clip. **NO reportes las apariciones individuales** de la marca dentro del propio comercial (en vallas, playeras, etc.).

2.  **Si el contexto es una 'Transmisión en Vivo':**
    Entonces, y solo entonces, procede a identificar y reportar cada aparición individual de la marca, eligiendo la categoría más apropiada de la siguiente lista:
    - **'Virtual'**: Gráfico generado por computadora superpuesto al campo mientras el juego continúa viéndose de fondo (ej. la botella de Yakult flotando).
    - **'Valla'**: La marca en las vallas LED físicas que rodean el campo.
    - **'Spot'**: Un gráfico que se sobrepone a la imagen sin estar integrado en el campo.
    - **'Banner'**: Un gráfico en los bordes de la pantalla.
    - **'Marcador'**: La marca junto al marcador de resultado.
    - **'Playera'**: El logo en la camiseta.
    - **'Menciones verbales'**: En comentarios o anuncios

### Formato de Salida Obligatorio
- Tu respuesta debe ser únicamente un objeto JSON con la clave "apariciones".
- Si no hay apariciones, devuelve: `{"apariciones": []}`.
- No incluyas explicaciones. Solo el JSON.

**Ejemplo de la estructura exacta que debes seguir:**
```json
{
  "apariciones": [
    {
      "marca": "Coca",
      "categoria": "Valla",
      "inicio": "00:11",
      "fin": "00:15"
    }
  ]
}

### Notas importantes
Los clips duran en total 16 segundos, entonces no puedes decir algo del estilo:
```json
{
  "apariciones": [
    {
      "marca": "Coca",
      "categoria": "Valla",
      "inicio": "00:19",
      "fin": "00:22"
    }
  ]
}

Si detectas más de una aparición en un solo clip, ten mucho cuidado con los tiempos

"""

    # Definimos la marca
    # marca_a_buscar = 'Caliente.mx'

    
    # Definimos el prompt
    prompt = "Busca en el video adjunto todas las apariciones (si es que existen) de la siguiente marca: "

    model = GenerativeModel('gemini-2.5-pro', system_instruction=system_instruction)


    # --- Hacemos la petición ---

    contenido = [video, prompt, marca_a_buscar]

    # Le pasamos a Gemini el contenido
    respuesta = model.generate_content(

        contents=contenido,
        generation_config=generation_config
        
    )


    # --- Retornamos la respuesta ---
    return respuesta.text

# %%
def reporteAlain(uri, marca_usuario):
    """
    Analiza el video y te devuelve la data de las apariciones de la marca.
    """
    # --- Configuración del modelo ---

    uri = f'gs://vboxiooof/Videos/Videos_Segmentados/{uri}'
    video = Part.from_uri(uri=uri, mime_type='video/mkv')
    generation_config = {'temperature': 0}

    # 1. Mueve tus instrucciones a una variable 'system_instruction'
    #    (He ajustado el f-string para que siga funcionando)
    system_instruction = f"""
        Eres un especialista en análisis de contenido deportivo con capacidad avanzada para detectar 
        marcas comerciales en videos. Sigue estrictamente estas instrucciones:

        1. BUSCAR ESPECÍFICAMENTE y ÚNICAMENTE la marca: {marca_usuario}
        2. Analizar TODO el video frame por frame si es necesario
        3. Considerar estas formas de aparición:
           - Menciones verbales (en comentarios o anuncios)
           - Tapetes al lado de porterías
           - Vallas electronicas
           - Marcador (que se encuentra al lado del marcador)
           - Banner (anuncios rectangulares, no cubren toda la pantalla, tienden a aparecer en la parte inferior o superior o a los lados de la pantalla)
           - Anuncios (comerciales de medio tiempo)
           - Virtual (tipo de anuncio que deja ver la cancha por detras, pueden ser animaciones)

        4. Para CADA detección proveer:
           - TIEMPO INICIO: (formato HH:MM:SS)
           - TIPO DE MEDIO: (seleccionar de lista anterior)
           - TAMAÑO: (pequeño <10% pantalla, mediano 10-30%, grande >30%)
           - UBICACIÓN: (esquina superior derecha, centro, etc.)
           - MENCION VERBAL: (si aplica, con tiempo exacto)

        5. Si NO se detecta la marca:
           - Indicar "Marca no encontrada después de análisis completo"
           - No dar detalles adicionales

        6. Formato de respuesta obligatorio:
        [INICIO ANÁLISIS]
        Video: {uri}
        Marca buscada: {marca_usuario}
        ---
        Detecciones:
        [Detección 1]
        Tiempo: HH:MM:SS - HH:MM:SS
        Tipo: [TIPO DE MEDIO]
        Tamaño: [TAMAÑO]
        Ubicación: [UBICACIÓN]
        Contexto: [DESCRIPCIÓN]
        Mencionada: [SI/NO] (HH:MM:SS si aplica)
        ---
        [Detección N]...
        ---
        Resumen: Total de apariciones: X
        [FIN ANÁLISIS]

        IMPORTANTE: Si el video es de baja calidad o la marca aparece muy breve, 
        igualmente reportarla si es identificable.
    """
    
    # 2. Inicializa el modelo PASANDO el system_instruction
    model = GenerativeModel('gemini-2.5-pro', system_instruction=system_instruction)

    # 3. Usa un prompt simple para la petición. La marca y las instrucciones ya están en el sistema.
    prompt = f"Analiza el video adjunto y encuentra la marca especificada en tus instrucciones."

    # --- Hacemos la petición ---
    
    # El contenido ahora solo necesita el video y el prompt sencillo
    contenido = [video, prompt]

    respuesta = model.generate_content(
        contents=contenido,
        generation_config=generation_config
    )

    # --- Retornamos la respuesta ---
    return respuesta.text

# %%
print(reporteGemini('mexicosta_segment_000.mkv', 'Caliente'))
# Out:
# ```json
# {
#   "apariciones": [
#     {
#       "marca": "Caliente",
#       "categoria": "Valla",
#       "inicio": "00:10",
#       "fin": "00:14"
#     }
#   ]
# }
# ```

# %%
print(reporteAlain('mexicosta_segment_000.mkv', 'Caliente'))
# Out:
# [INICIO ANÁLISIS]
# Video: gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_000.mkv
# Marca buscada: Caliente
# ---
# Detecciones:
# [Detección 1]
# Tiempo: 00:00:10 - 00:00:15
# Tipo: Valla electronica
# Tamaño: pequeño
# Ubicación: esquina inferior derecha (en el fondo de la ventana del comentarista)
# Contexto: El logo de "Caliente.mx" es visible en una valla electrónica roja en el estadio, que se muestra en el fondo de la ventana del comentarista.
# Mencionada: NO
# ---
# Resumen: Total de apariciones: 1
# [FIN ANÁLISIS]

# %%
def pasar_json(respuesta_gemini: str):
    """
    Limpia la respuesta de texto de Gemini y la convierte en un objeto JSON.
    
    Args:
        respuesta_gemini: La cadena de texto cruda devuelta por `respuesta.text`.

    Returns:
        Un diccionario o lista de Python, o None si ocurre un error.
    """
    try:
        # 1. Limpia el string de los marcadores de Markdown y espacios en blanco
        # Usamos removeprefix y removesuffix que son más seguros que replace
        json_limpio_str = respuesta_gemini.strip().removeprefix('```json').removesuffix('```').strip()
        
        # 2. Convierte el string limpio en un objeto JSON (diccionario/lista)
        return json.loads(json_limpio_str)
        
    except json.JSONDecodeError:
        print("Error: La respuesta de Gemini no pudo ser decodificada como JSON válido.")
        return None
    except Exception as e:
        print(f"Ocurrió un error inesperado: {e}")
        return None

# %% [markdown]
# # **Pruebas**

# %% [markdown]
# ### **Primer tiempo**

# %% [markdown]
# ##### Pruebas con mi sistem prompt

# %%
# Marcamos el inicio del programa
start_time = time.time()


# Obtenemos la lista de videos
uris = obtener_nombres_de_archivos(nombre_bucket=BUCKET_NAME, nombre_carpeta=VIDEO_FOLDER_PATH)

uris

data = [] # Aquí vamos a guardar los JSON


for i in range(233):
    print(f'Vamos en {uris[i]}')
    data.append( ['gs://vboxiooof/Videos/Videos_Segmentados/'+uris[i], pasar_json(reporteGemini(uris[i]))] ) # Guardamos tuplas (uri, info)


end_time = time.time()


print(f'El proceso duró: {end_time - start_time}')
# Out:
# Vamos en mexicosta_segment_000.mkv
# Vamos en mexicosta_segment_001.mkv
# Vamos en mexicosta_segment_002.mkv
# Vamos en mexicosta_segment_003.mkv
# Vamos en mexicosta_segment_004.mkv
# Vamos en mexicosta_segment_005.mkv
# Vamos en mexicosta_segment_006.mkv
# Vamos en mexicosta_segment_007.mkv
# Vamos en mexicosta_segment_008.mkv
# Vamos en mexicosta_segment_009.mkv
# Vamos en mexicosta_segment_010.mkv
# Vamos en mexicosta_segment_011.mkv
# Vamos en mexicosta_segment_012.mkv
# Vamos en mexicosta_segment_013.mkv
# Vamos en mexicosta_segment_014.mkv
# Vamos en mexicosta_segment_015.mkv
# Vamos en mexicosta_segment_016.mkv
# Vamos en mexicosta_segment_017.mkv
# Vamos en mexicosta_segment_018.mkv
# Vamos en mexicosta_segment_019.mkv
# Vamos en mexicosta_segment_020.mkv
# Vamos en mexicosta_segment_021.mkv
# Vamos en mexicosta_segment_022.mkv
# Vamos en mexicosta_segment_023.mkv
# Vamos en mexicosta_segment_024.mkv
# Vamos en mexicosta_segment_025.mkv
# Vamos en mexicosta_segment_026.mkv
# Vamos en mexicosta_segment_027.mkv
# Vamos en mexicosta_segment_028.mkv
# Vamos en mexicosta_segment_029.mkv
# Vamos en mexicosta_segment_030.mkv
# Vamos en mexicosta_segment_031.mkv
# Vamos en mexicosta_segment_032.mkv
# Vamos en mexicosta_segment_033.mkv
# Vamos en mexicosta_segment_034.mkv
# Vamos en mexicosta_segment_035.mkv
# Vamos en mexicosta_segment_036.mkv
# Vamos en mexicosta_segment_037.mkv
# Vamos en mexicosta_segment_038.mkv
# Vamos en mexicosta_segment_039.mkv
# Vamos en mexicosta_segment_040.mkv
# Vamos en mexicosta_segment_041.mkv
# Vamos en mexicosta_segment_042.mkv
# Vamos en mexicosta_segment_043.mkv
# Vamos en mexicosta_segment_044.mkv
# Vamos en mexicosta_segment_045.mkv
# Vamos en mexicosta_segment_046.mkv
# Vamos en mexicosta_segment_047.mkv
# Vamos en mexicosta_segment_048.mkv
# Vamos en mexicosta_segment_049.mkv
# Vamos en mexicosta_segment_050.mkv
# Vamos en mexicosta_segment_051.mkv
# Vamos en mexicosta_segment_052.mkv
# Vamos en mexicosta_segment_053.mkv
# Vamos en mexicosta_segment_054.mkv
# Vamos en mexicosta_segment_055.mkv
# Vamos en mexicosta_segment_056.mkv
# Vamos en mexicosta_segment_057.mkv
# Vamos en mexicosta_segment_058.mkv
# Vamos en mexicosta_segment_059.mkv
# Vamos en mexicosta_segment_060.mkv
# Vamos en mexicosta_segment_061.mkv
# Vamos en mexicosta_segment_062.mkv
# Vamos en mexicosta_segment_063.mkv
# Vamos en mexicosta_segment_064.mkv
# Vamos en mexicosta_segment_065.mkv
# Vamos en mexicosta_segment_066.mkv
# Vamos en mexicosta_segment_067.mkv
# Vamos en mexicosta_segment_068.mkv
# Vamos en mexicosta_segment_069.mkv
# Vamos en mexicosta_segment_070.mkv
# Vamos en mexicosta_segment_071.mkv
# Vamos en mexicosta_segment_072.mkv
# Vamos en mexicosta_segment_073.mkv
# Vamos en mexicosta_segment_074.mkv
# Vamos en mexicosta_segment_075.mkv
# Vamos en mexicosta_segment_076.mkv
# Vamos en mexicosta_segment_077.mkv
# Vamos en mexicosta_segment_078.mkv
# Vamos en mexicosta_segment_079.mkv
# Vamos en mexicosta_segment_080.mkv
# Vamos en mexicosta_segment_081.mkv
# Vamos en mexicosta_segment_082.mkv
# Vamos en mexicosta_segment_083.mkv
# Vamos en mexicosta_segment_084.mkv
# Vamos en mexicosta_segment_085.mkv
# Vamos en mexicosta_segment_086.mkv
# Vamos en mexicosta_segment_087.mkv
# Vamos en mexicosta_segment_088.mkv
# Vamos en mexicosta_segment_089.mkv
# Vamos en mexicosta_segment_090.mkv
# Vamos en mexicosta_segment_091.mkv
# Vamos en mexicosta_segment_092.mkv
# Vamos en mexicosta_segment_093.mkv
# Vamos en mexicosta_segment_094.mkv
# Vamos en mexicosta_segment_095.mkv
# Vamos en mexicosta_segment_096.mkv
# Vamos en mexicosta_segment_097.mkv
# Vamos en mexicosta_segment_098.mkv
# Vamos en mexicosta_segment_099.mkv
# Vamos en mexicosta_segment_100.mkv
# Vamos en mexicosta_segment_101.mkv
# Vamos en mexicosta_segment_102.mkv
# Vamos en mexicosta_segment_103.mkv
# Vamos en mexicosta_segment_104.mkv
# Vamos en mexicosta_segment_105.mkv
# Vamos en mexicosta_segment_106.mkv
# Vamos en mexicosta_segment_107.mkv
# Vamos en mexicosta_segment_108.mkv
# Vamos en mexicosta_segment_109.mkv
# Vamos en mexicosta_segment_110.mkv
# Vamos en mexicosta_segment_111.mkv
# Vamos en mexicosta_segment_112.mkv
# Vamos en mexicosta_segment_113.mkv
# Vamos en mexicosta_segment_114.mkv
# Vamos en mexicosta_segment_115.mkv
# Vamos en mexicosta_segment_116.mkv
# Vamos en mexicosta_segment_117.mkv
# Vamos en mexicosta_segment_118.mkv
# Vamos en mexicosta_segment_119.mkv
# Vamos en mexicosta_segment_120.mkv
# Vamos en mexicosta_segment_121.mkv
# Vamos en mexicosta_segment_122.mkv
# Vamos en mexicosta_segment_123.mkv
# Vamos en mexicosta_segment_124.mkv
# Vamos en mexicosta_segment_125.mkv
# Vamos en mexicosta_segment_126.mkv
# Vamos en mexicosta_segment_127.mkv
# Vamos en mexicosta_segment_128.mkv
# Vamos en mexicosta_segment_129.mkv
# Vamos en mexicosta_segment_130.mkv
# Vamos en mexicosta_segment_131.mkv
# Vamos en mexicosta_segment_132.mkv
# Vamos en mexicosta_segment_133.mkv
# Vamos en mexicosta_segment_134.mkv
# Vamos en mexicosta_segment_135.mkv
# Vamos en mexicosta_segment_136.mkv
# Vamos en mexicosta_segment_137.mkv
# Vamos en mexicosta_segment_138.mkv
# Vamos en mexicosta_segment_139.mkv
# Vamos en mexicosta_segment_140.mkv
# Vamos en mexicosta_segment_141.mkv
# Vamos en mexicosta_segment_142.mkv
# Vamos en mexicosta_segment_143.mkv
# Vamos en mexicosta_segment_144.mkv
# Vamos en mexicosta_segment_145.mkv
# Vamos en mexicosta_segment_146.mkv
# Vamos en mexicosta_segment_147.mkv
# Vamos en mexicosta_segment_148.mkv
# Vamos en mexicosta_segment_149.mkv
# Vamos en mexicosta_segment_150.mkv
# Vamos en mexicosta_segment_151.mkv
# Vamos en mexicosta_segment_152.mkv
# Vamos en mexicosta_segment_153.mkv
# Vamos en mexicosta_segment_154.mkv
# Vamos en mexicosta_segment_155.mkv
# Vamos en mexicosta_segment_156.mkv
# Vamos en mexicosta_segment_157.mkv
# Vamos en mexicosta_segment_158.mkv
# Vamos en mexicosta_segment_159.mkv
# Vamos en mexicosta_segment_160.mkv
# Vamos en mexicosta_segment_161.mkv
# Vamos en mexicosta_segment_162.mkv
# Vamos en mexicosta_segment_163.mkv
# Vamos en mexicosta_segment_164.mkv
# Vamos en mexicosta_segment_165.mkv
# Vamos en mexicosta_segment_166.mkv
# Vamos en mexicosta_segment_167.mkv
# Vamos en mexicosta_segment_168.mkv
# Vamos en mexicosta_segment_169.mkv
# Vamos en mexicosta_segment_170.mkv
# Vamos en mexicosta_segment_171.mkv
# Vamos en mexicosta_segment_172.mkv
# Vamos en mexicosta_segment_173.mkv
# Vamos en mexicosta_segment_174.mkv
# Vamos en mexicosta_segment_175.mkv
# Vamos en mexicosta_segment_176.mkv
# Vamos en mexicosta_segment_177.mkv
# Vamos en mexicosta_segment_178.mkv
# Vamos en mexicosta_segment_179.mkv
# Vamos en mexicosta_segment_180.mkv
# Vamos en mexicosta_segment_181.mkv
# Vamos en mexicosta_segment_182.mkv
# Vamos en mexicosta_segment_183.mkv
# Vamos en mexicosta_segment_184.mkv
# Vamos en mexicosta_segment_185.mkv
# Vamos en mexicosta_segment_186.mkv
# Vamos en mexicosta_segment_187.mkv
# Vamos en mexicosta_segment_188.mkv
# Vamos en mexicosta_segment_189.mkv
# Vamos en mexicosta_segment_190.mkv
# Vamos en mexicosta_segment_191.mkv
# Vamos en mexicosta_segment_192.mkv
# Vamos en mexicosta_segment_193.mkv
# Vamos en mexicosta_segment_194.mkv
# Vamos en mexicosta_segment_195.mkv
# Vamos en mexicosta_segment_196.mkv
# Vamos en mexicosta_segment_197.mkv
# Vamos en mexicosta_segment_198.mkv
# Vamos en mexicosta_segment_199.mkv
# Vamos en mexicosta_segment_200.mkv
# Vamos en mexicosta_segment_201.mkv
# Vamos en mexicosta_segment_202.mkv
# Vamos en mexicosta_segment_203.mkv
# Vamos en mexicosta_segment_204.mkv
# Vamos en mexicosta_segment_205.mkv
# Vamos en mexicosta_segment_206.mkv
# Vamos en mexicosta_segment_207.mkv
# Vamos en mexicosta_segment_208.mkv
# Vamos en mexicosta_segment_209.mkv
# Vamos en mexicosta_segment_210.mkv
# Vamos en mexicosta_segment_211.mkv
# Vamos en mexicosta_segment_212.mkv
# Vamos en mexicosta_segment_213.mkv
# Vamos en mexicosta_segment_214.mkv
# Vamos en mexicosta_segment_215.mkv
# Vamos en mexicosta_segment_216.mkv
# Vamos en mexicosta_segment_217.mkv
# Vamos en mexicosta_segment_218.mkv
# Vamos en mexicosta_segment_219.mkv
# Vamos en mexicosta_segment_220.mkv
# Vamos en mexicosta_segment_221.mkv
# Vamos en mexicosta_segment_222.mkv
# Vamos en mexicosta_segment_223.mkv
# Vamos en mexicosta_segment_224.mkv
# Vamos en mexicosta_segment_225.mkv
# Vamos en mexicosta_segment_226.mkv
# Vamos en mexicosta_segment_227.mkv
# Vamos en mexicosta_segment_228.mkv
# Vamos en mexicosta_segment_229.mkv
# Vamos en mexicosta_segment_230.mkv
# Vamos en mexicosta_segment_231.mkv
# Vamos en mexicosta_segment_232.mkv
# El proceso duró: 3326.67333817482

# %%
print(reporteGemini('mexicosta_segment_052.mkv', 'Caliente'))
# Out:
# ```json
# {
#   "apariciones": [
#     {
#       "marca": "Caliente",
#       "categoria": "Banner",
#       "inicio": "00:00",
#       "fin": "00:04"
#     },
#     {
#       "marca": "Caliente",
#       "categoria": "Valla",
#       "inicio": "00:00",
#       "fin": "00:16"
#     },
#     {
#       "marca": "Caliente",
#       "categoria": "Marcador",
#       "inicio": "00:07",
#       "fin": "00:08"
#     },
#     {
#       "marca": "Caliente",
#       "categoria": "Marcador",
#       "inicio": "00:09",
#       "fin": "00:11"
#     },
#     {
#       "marca": "Caliente",
#       "categoria": "Marcador",
#       "inicio": "00:13",
#       "fin": "00:15"
#     }
#   ]
# }
# ```

# %%
print(reporteAlain('mexicosta_segment_052.mkv', 'Caliente'))
# Out:
# [INICIO ANÁLISIS]
# Video: gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_052.mkv
# Marca buscada: Caliente
# ---
# Detecciones:
# [Detección 1]
# Tiempo: 00:00:00 - 00:00:04
# Tipo: Banner
# Tamaño: Grande (>30%)
# Ubicación: Inferior y lateral izquierdo
# Contexto: Un banner rojo en la parte inferior muestra el logo de Caliente.mx, el texto "CASA DE APUESTAS OFICIAL" y momios para tiros de esquina. Simultáneamente, un banner vertical en el lado izquierdo muestra el logo y una app en un teléfono.
# Mencionada: NO
# ---
# [Detección 2]
# Tiempo: 00:00:00 - 00:00:31
# Tipo: Vallas electronicas
# Tamaño: Pequeño (<10%)
# Ubicación: Fondo, detrás de la portería
# Contexto: Las vallas publicitarias electrónicas que rodean el campo de juego muestran repetidamente el logo y el texto "caliente.mx".
# Mencionada: NO
# ---
# [Detección 3]
# Tiempo: 00:00:22 - 00:00:31
# Tipo: Marcador
# Tamaño: Pequeño (<10%)
# Ubicación: Esquina superior izquierda
# Contexto: El logo de "Caliente.mx" aparece en un recuadro rojo justo al lado del marcador del partido.
# Mencionada: NO
# ---
# Resumen: Total de apariciones: 3
# [FIN ANÁLISIS]

# %%
data
# Out:
# [['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_000.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:11',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_001.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:01',
#      'fin': '00:06'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_002.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_003.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Anuncio',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_004.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_005.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_006.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_007.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_008.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_009.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_010.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_011.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_012.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_013.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_014.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_015.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_016.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_017.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_018.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_019.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Anuncio',
#      'inicio': '00:00',
#      'fin': '00:16'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_020.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_021.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:10',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_022.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:00',
#      'fin': '00:15'},
#     {'marca': 'Caliente',
#      'categoria': 'Banner',
#      'inicio': '00:00',
#      'fin': '00:15'},
#     {'marca': 'Caliente',
#      'categoria': 'Menciones verbales',
#      'inicio': '00:10',
#      'fin': '00:12'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_023.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_024.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Anuncio',
#      'inicio': '00:00',
#      'fin': '00:05'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_025.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_026.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_027.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:08',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_028.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:14',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_029.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_030.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:13',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_031.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:06',
#      'fin': '00:10'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_032.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_033.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_034.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_035.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_036.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_037.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Banner',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_038.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_039.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_040.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_041.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Anuncio',
#      'inicio': '00:11',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_042.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Anuncio',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_043.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Anuncio',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_044.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Anuncio',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_045.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Anuncio',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_046.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:07',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_047.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Banner',
#      'inicio': '00:15',
#      'fin': '00:16'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_048.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_049.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Banner',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_050.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Banner',
#      'inicio': '00:05',
#      'fin': '00:15'},
#     {'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:11',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_051.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:00',
#      'fin': '00:15'},
#     {'marca': 'Caliente',
#      'categoria': 'Menciones verbales',
#      'inicio': '00:07',
#      'fin': '00:14'},
#     {'marca': 'Caliente',
#      'categoria': 'Banner',
#      'inicio': '00:07',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_052.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Banner',
#      'inicio': '00:00',
#      'fin': '00:04'},
#     {'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:00',
#      'fin': '00:31'},
#     {'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:22',
#      'fin': '00:31'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_053.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:02'},
#     {'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:11',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_054.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_055.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_056.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:03',
#      'fin': '00:14'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_057.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_058.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_059.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:16'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_060.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_061.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Banner',
#      'inicio': '00:00',
#      'fin': '00:15'},
#     {'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:12',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_062.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_063.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:08',
#      'fin': '00:16'},
#     {'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:10',
#      'fin': '00:16'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_064.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_065.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Banner',
#      'inicio': '00:00',
#      'fin': '00:15'},
#     {'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:08',
#      'fin': '00:11'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_066.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:00',
#      'fin': '00:15'},
#     {'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_067.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_068.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:16'},
#     {'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:10',
#      'fin': '00:16'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_069.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_070.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:00',
#      'fin': '00:16'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_071.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:00',
#      'fin': '00:01'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_072.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_073.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_074.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_075.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_076.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Virtual',
#      'inicio': '00:15',
#      'fin': '00:17'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_077.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_078.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:00',
#      'fin': '00:04'},
#     {'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:10',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_079.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Banner',
#      'inicio': '00:09',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_080.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:00',
#      'fin': '00:08'},
#     {'marca': 'Caliente',
#      'categoria': 'Menciones verbales',
#      'inicio': '00:01',
#      'fin': '00:04'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_081.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Banner',
#      'inicio': '00:11',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_082.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:13',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_083.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_084.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:07',
#      'fin': '00:13'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_085.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_086.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_087.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:12',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_088.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_089.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_090.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_091.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_092.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_093.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_094.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_095.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_096.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_097.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:13',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_098.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_099.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_100.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_101.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_102.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_103.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_104.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_105.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_106.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_107.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_108.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:02',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_109.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_110.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:00',
#      'fin': '00:02'},
#     {'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:11',
#      'fin': '00:16'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_111.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_112.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_113.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_114.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_115.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:16'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_116.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:09',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_117.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:00',
#      'fin': '00:13'},
#     {'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:15',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_118.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_119.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_120.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_121.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_122.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_123.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_124.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_125.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_126.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_127.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_128.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_129.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:00',
#      'fin': '00:21'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_130.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_131.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:15',
#      'fin': '00:35'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_132.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:14',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_133.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_134.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_135.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_136.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_137.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_138.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_139.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:14',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_140.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_141.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:12',
#      'fin': '00:13'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_142.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:13',
#      'fin': '00:18'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_143.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_144.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:00',
#      'fin': '00:11'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_145.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_146.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:15',
#      'fin': '00:16'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_147.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_148.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_149.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_150.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:12',
#      'fin': '00:16'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_151.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_152.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_153.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:01',
#      'fin': '00:27'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_154.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_155.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:04',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_156.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_157.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_158.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:14',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_159.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:11',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_160.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_161.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_162.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_163.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_164.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_165.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_166.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_167.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_168.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:11',
#      'fin': '00:13'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_169.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_170.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_171.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_172.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_173.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:00',
#      'fin': '00:06'},
#     {'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:13',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_174.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:12',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_175.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_176.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:14',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_177.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_178.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_179.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_180.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_181.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_182.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_183.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_184.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_185.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:10',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_186.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:10',
#      'fin': '00:12'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_187.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_188.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_189.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_190.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_191.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:06',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_192.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_193.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_194.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_195.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_196.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:05',
#      'fin': '00:16'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_197.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:14',
#      'fin': '00:16'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_198.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_199.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_200.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_201.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:03'},
#     {'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:08',
#      'fin': '00:15'},
#     {'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:08',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_202.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_203.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:08',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_204.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:11'},
#     {'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:11',
#      'fin': '00:16'},
#     {'marca': 'Caliente',
#      'categoria': 'Playera',
#      'inicio': '00:13',
#      'fin': '00:16'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_205.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_206.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:09',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_207.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:02',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_208.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:15'},
#     {'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:07',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_209.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:00',
#      'fin': '00:15'},
#     {'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_210.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:02',
#      'fin': '00:15'},
#     {'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:05',
#      'fin': '00:05'},
#     {'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:15',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_211.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_212.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:05'},
#     {'marca': 'Caliente',
#      'categoria': 'Menciones verbales',
#      'inicio': '00:02',
#      'fin': '00:04'},
#     {'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:05',
#      'fin': '00:15'},
#     {'marca': 'Caliente',
#      'categoria': 'Menciones verbales',
#      'inicio': '00:09',
#      'fin': '00:12'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_213.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:00',
#      'fin': '00:02'},
#     {'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:02',
#      'fin': '00:15'},
#     {'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_214.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:16'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_215.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_216.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_217.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:15'},
#     {'marca': 'Caliente',
#      'categoria': 'Banner',
#      'inicio': '00:12',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_218.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:00',
#      'fin': '00:15'},
#     {'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:05',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_219.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:09',
#      'fin': '00:14'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_220.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Marcador',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_221.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:00',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_222.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Spot',
#      'inicio': '00:00',
#      'fin': '00:15'},
#     {'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:03',
#      'fin': '00:04'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_223.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:04',
#      'fin': '00:14'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_224.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:01',
#      'fin': '00:08'},
#     {'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:11',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_225.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Valla',
#      'inicio': '00:07',
#      'fin': '00:09'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_226.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_227.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Anuncio',
#      'inicio': '00:08',
#      'fin': '00:15'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_228.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Anuncio',
#      'inicio': '00:00',
#      'fin': '00:12'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_229.mkv',
#   {'apariciones': [{'marca': 'Caliente',
#      'categoria': 'Anuncio',
#      'inicio': '00:07',
#      'fin': '00:16'}]}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_230.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_231.mkv',
#   {'apariciones': []}],
#  ['gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_232.mkv',
#   {'apariciones': []}]]

# %% [markdown]
# * 000 erroneo (no sale nada)
# * 003 erroneo (no sale nada)
# * 019 erroneo (no sale nada)
# * 021 erroneo (no es spot, es virtual)
# * 022 erroneo (no es ni spot, ni banner, es virtual)
# * 023 erroneo (no es spot, es virtual)
# * 027 erroneo (no sale nada)
# * 028 erroneo (no sale nada)
# * 001 erroneo (no sale nada)
# * 030 erroneo (no sale nada)
# * 031 erroneo (no sale nada)
# * 032 erroneo (no sale nada)
# * 037 erroneo (no sale nada)
# * 043 erroneo (no es anuncio, es virtual)
# * 044 erroneo (no es anuncio, es virtual)
# * 045 erroneo (no es anuncio, es virtual, y los tiempos van de 0 a 2, no de 0 a 15)
# * 046 erroneo (no sale nada)
# * 047 erroneo (no sale nada)
# * 049 erroneo (no sale nada)
# * 050 erroneo (no sale nada)

# %%
print(reporteAlain('mexicosta_segment_001.mkv', 'Caliente.mx'))
# Out:
# [INICIO ANÁLISIS]
# Video: gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_001.mkv
# Marca buscada: Caliente.mx
# ---
# Detecciones:
# [Detección 1]
# Tiempo: 00:00:02 - 00:00:07
# Tipo: Vallas electronicas
# Tamaño: Mediano
# Ubicación: Centro, fondo del campo
# Contexto: La marca aparece de forma prominente en las vallas electrónicas de color rojo que rodean el campo de juego, durante la repetición de una jugada de gol.
# Mencionada: NO
# ---
# Resumen: Total de apariciones: 1
# [FIN ANÁLISIS]

# %%
print(reporteGemini('mexicosta_segment_001.mkv', 'Caliente'))
# Out:
# ```json
# {
#   "apariciones": [
#     {
#       "marca": "Caliente",
#       "categoria": "Valla",
#       "inicio": "00:02",
#       "fin": "00:06"
#     }
#   ]
# }
# ```

# %% [markdown]
# ##### Pruebas con el sistem prompt de Alain

# %%
# Marcamos el inicio del programa
start_time = time.time()


# Obtenemos la lista de videos
uris = obtener_nombres_de_archivos(nombre_bucket=BUCKET_NAME, nombre_carpeta=VIDEO_FOLDER_PATH)

uris

data = [] # Aquí vamos a guardar los JSON


for i in range(233):
    print(reporteAlain(uris[i], 'Caliente'))
    print('-'*100)


end_time = time.time()


print(f'El proceso duró: {end_time - start_time}')
# Out:
# [INICIO ANÁLISIS]
# Video: gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_000.mkv
# Marca buscada: Caliente
# ---
# Detecciones:
# [Detección 1]
# Tiempo: 00:00:10 - 00:00:15
# Tipo: Valla electronica
# Tamaño: pequeño
# Ubicación: esquina inferior derecha (en el fondo de la ventana del comentarista)
# Contexto: El logo de "Caliente.mx" es visible en una valla electrónica roja en el estadio, que se muestra en el fondo de la ventana del comentarista.
# Mencionada: NO
# ---
# Resumen: Total de apariciones: 1
# [FIN ANÁLISIS]
# ----------------------------------------------------------------------------------------------------
# [INICIO ANÁLISIS]
# Video: gs://vboxiooof/Videos/Videos_Segmentados/mexicosta_segment_001.mkv
# Marca buscada: Caliente
# ---
# Detecciones:
# [Detección 1]
# Tiempo: 00:00:02 - 00:00:07
# Tipo: Vallas electronicas
# Tamaño: Mediano
# Ubicación: Perímetro del campo
# Contexto: La marca "caliente.mx" se muestra en las vallas electrónicas de color rojo que rodean el campo, tanto en la línea de banda como detrás de la portería, durante la repetición de una jugada de gol. La visibilidad es alta, especialmente en el acercamiento al jugador que celebra en el 00:00:06.
# Mencionada: NO
# ---
# Resumen: Total de apariciones: 1
# [FIN ANÁLISIS]
# ----------------------------------------------------------------------------------------------------
# El proceso duró: 43.09658908843994
